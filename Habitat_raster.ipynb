# %%
import numpy as np
import rasterio
from rasterio.plot import show

raster = rasterio.open("iucn_habitatclassification_composite_lvl2_ver001.tif")

# %%
sjer_chm_data = rxr.open_rasterio(raster, masked=False).squeeze()

# %%
type(sjer_chm_data)
np.unique(sjer_chm_data.values)
# Out:
# array([   0,  100,  101,  102,  103,  104,  105,  106,  107,  108,  109,
#         201,  202,  300,  301,  302,  303,  304,  305,  306,  307,  308,
#         400,  401,  402,  403,  404,  405,  406,  407,  500,  502,  503,
#         504,  505,  506,  507,  510,  511,  513,  514,  600,  801,  802,
#         803, 1401, 1402, 1403, 1405], dtype=int16)

# %%
show(sjer_chm_data)
# Out:
# <AxesSubplot:>

# %%
import rioxarray as rxr

# %%
type(raster)
# Out:
# rasterio.io.DatasetReader
