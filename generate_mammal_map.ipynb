# %%
# %run -m generate_maps
from datetime import datetime
start = datetime.now().time() 
print("start =", start)
inter_grouped = overlay_and_sum_grid(500,delta =(60000, 60000))
end = datetime.now().time() 
print("end =", end)
# Out:
# start = 17:51:28.546469
# got data
# grid generated
# overlay_and_sum done
# end = 08:07:43.755999

# %%
# %run -m generate_maps
# inter_grouped.to_file('map_data/gridded_mammal_mass_jan21/gridded_mammal_mass.shp')
# foo = gpd.read_file('map_data/gridded_mammal_mass_jan21/gridded_mammal_mass.shp')
# foo = foo.rename(columns={"total_ma_3": "total_mass_kg_km2"})
gen_grid_plot(inter_grouped)
